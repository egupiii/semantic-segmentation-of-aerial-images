# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "drive/My Drive"
# Out:
# /content/drive/My Drive

# %%
import os
import random
import sys
import warnings
from itertools import chain

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL.Image
import tensorflow as tf
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.core import Activation, Lambda
from keras.layers.merge import concatenate
from keras.layers.pooling import MaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing.image import (ImageDataGenerator, array_to_img,
                                       img_to_array, load_img)
from skimage.io import concatenate_images, imread, imshow
from skimage.morphology import label
from skimage.transform import resize
from tqdm import tnrange, tqdm_notebook

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Set hyperparameters

# Shape
im_height = 256
im_width = 256
im_chan = 1

# Path
path_train = "new_dataset/train/rwanda/"
path_test = "new_dataset/test/rwanda/"

# Number of images
n_original_train_images = 50
n_all_train_images = 550
n_test_images = 30

# %%
# Resize
X_train = np.zeros((n_all_train_images, im_height,
                    im_width, im_chan), dtype=np.uint8)
Y_train = np.zeros((n_all_train_images, im_height, im_width, im_chan))

num = -1
for id_ in range(n_original_train_images):
    path = path_train
    num += 1

    # Original images
    img = load_img(path + "image+augmentation/" + str(id_) + ".png")
    # Get 1 channel from 3 channels, RGB
    x = img_to_array(img)[:, :, 1]
    x = resize(x, (im_height, im_width, 1),
               mode="constant", preserve_range=True)
    X_train[num] = x

    # Mask images
    mask = PIL.Image.open(path + "label+augmentation/" + str(id_) + ".png")
    mask = np.asarray(mask)
    Y_train[num] = resize(mask, (im_height, im_width, 1),
                          mode="constant", preserve_range=True)

    # Augmented images
    for i in range(10):
        num += 1

        # Original
        img_aug = load_img(path + "image+augmentation/" +
                           str(id_) + "-" + str(i) + ".png")
        x = img_to_array(img_aug)[:, :, 1]
        x = resize(x, (im_height, im_width, 1),
                   mode="constant", preserve_range=True)
        X_train[num] = x

        # Mask
        mask_aug = PIL.Image.open(
            path + "label+augmentation/" + str(id_) + "-" + str(i) + ".png")
        mask_aug = np.asarray(mask_aug)
        Y_train[num] = resize(mask_aug, (im_height, im_width, 1),
                              mode="constant", preserve_range=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# Define IoU metrics


def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Bulid U-Net model


def theacher_model():
    # Shape: (256, 256, 1)
    inputs = Input((im_height, im_width, im_chan))
    # Change pixel values to 0-1
    s = Lambda(lambda x: x / 255)(inputs)

    # Filter: (3✕3), Number of filters:8
    # N_out = (N_in + 2P - F)/s +1
    #       = (128 +0 - 2)/2 + 1
    #       = 64
    tc1 = Conv2D(8, (3, 3), activation='relu', padding='same')(s)
    tc1 = Conv2D(8, (3, 3), activation='relu', padding='same')(tc1)
    tp1 = MaxPooling2D((2, 2))(tc1)
    # Shape: (64,64,8)

    # N_in: (64,64,8)
    tc2 = Conv2D(16, (3, 3), activation='relu', padding='same')(tp1)
    tc2 = Conv2D(16, (3, 3), activation='relu', padding='same')(tc2)
    tp2 = MaxPooling2D((2, 2))(tc2)
    # N_out: (32,32,16)

    tc3 = Conv2D(32, (3, 3), activation='relu', padding='same')(tp2)
    tc3 = Conv2D(32, (3, 3), activation='relu', padding='same')(tc3)
    tp3 = MaxPooling2D((2, 2))(tc3)
    # N_out: (16, 16, 32)

    tc4 = Conv2D(64, (3, 3), activation='relu', padding='same')(tp3)
    tc4 = Conv2D(64, (3, 3), activation='relu', padding='same')(tc4)
    tp4 = MaxPooling2D(pool_size=(2, 2))(tc4)
    # N_out: (8,8,64)

    tc5 = Conv2D(128, (3, 3), activation='relu', padding='same')(tp4)
    tc5 = Conv2D(128, (3, 3), activation='relu', padding='same')(tc5)
    # N_out: (8, 8, 128)

    tu6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(tc5)
    tu6 = concatenate([tu6, tc4])
    tc6 = Conv2D(64, (3, 3), activation='relu', padding='same')(tu6)
    tc6 = Conv2D(64, (3, 3), activation='relu', padding='same')(tc6)
    # N_out: (16,16, 64)

    tu7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(tc6)
    tu7 = concatenate([tu7, tc3])
    tc7 = Conv2D(32, (3, 3), activation='relu', padding='same')(tu7)
    tc7 = Conv2D(32, (3, 3), activation='relu', padding='same')(tc7)
    # N_out: (32,32, 32)

    tu8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(tc7)
    tu8 = concatenate([tu8, tc2])
    tc8 = Conv2D(16, (3, 3), activation='relu', padding='same')(tu8)
    tc8 = Conv2D(16, (3, 3), activation='relu', padding='same')(tc8)
    # N_out: (64, 64, 16)

    tu9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(tc8)
    # N_out: (128, 128, 8)
    tu9 = concatenate([tu9, tc1], axis=3)
    tc9 = Conv2D(8, (3, 3), activation='relu', padding='same')(tu9)
    tc9 = Conv2D(8, (3, 3), activation='relu', padding='same')(tc9)

    tc10 = Conv2D(1, (1, 1))(tc9)
    teacher_outputs = Activation('sigmoid')(tc10)

    return Model(inputs=[inputs], outputs=[teacher_outputs])


t_model = theacher_model()
t_model.compile(optimizer='adam', loss='binary_crossentropy',
                metrics=[mean_iou])
t_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-5-4df1f46d7c15>:5: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:259: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:1138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:1155: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 8)  80          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  584         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 16) 2320        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   8224        conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 8)  520         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 16) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 8)  1160        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 8)  584         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  9           conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 1)  0           conv2d_19[0][0]
# ==================================================================================================
# Total params: 485,673
# Trainable params: 485,673
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit

results = t_model.fit(
    X_train, Y_train, validation_split=0.1, batch_size=8, epochs=300)
# Out:
# Train on 495 samples, validate on 55 samples
# Epoch 1/300
# 495/495 [==============================] - 9s 18ms/step - loss: 0.2218 - mean_iou: 0.4860 - val_loss: 0.0209 - val_mean_iou: 0.4951
# Epoch 2/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4967 - val_loss: 0.0209 - val_mean_iou: 0.4975
# Epoch 3/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4980 - val_loss: 0.0209 - val_mean_iou: 0.4983
# Epoch 4/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4985 - val_loss: 0.0209 - val_mean_iou: 0.4987
# Epoch 5/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4988 - val_loss: 0.0209 - val_mean_iou: 0.4989
# Epoch 6/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4990 - val_loss: 0.0209 - val_mean_iou: 0.4990
# Epoch 7/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4991 - val_loss: 0.0209 - val_mean_iou: 0.4991
# Epoch 8/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4992 - val_loss: 0.0209 - val_mean_iou: 0.4992
# Epoch 9/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4992 - val_loss: 0.0209 - val_mean_iou: 0.4992
# Epoch 10/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4992 - val_loss: 0.0209 - val_mean_iou: 0.4993
# Epoch 11/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4993 - val_loss: 0.0209 - val_mean_iou: 0.4993
# Epoch 12/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4993 - val_loss: 0.0209 - val_mean_iou: 0.4993
# Epoch 13/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 14/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 15/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 16/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 17/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 18/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 19/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 20/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 21/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 22/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 23/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 24/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 25/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 26/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 27/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 28/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 29/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 30/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 31/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 32/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 33/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 34/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 35/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 36/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 37/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 38/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 39/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 40/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 41/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 42/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 43/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 44/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 45/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 46/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 47/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 48/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 49/300
# 495/495 [==============================] - 5s 10ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 50/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 51/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 52/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 53/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 54/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 55/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 56/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 57/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 58/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 59/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 60/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 61/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 62/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 63/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 64/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 65/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 66/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 67/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 68/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 69/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 70/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 71/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 72/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 73/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 74/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 75/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 76/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 77/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 78/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 79/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 80/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 81/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 82/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 83/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 84/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 85/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 86/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 87/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 88/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 89/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 90/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 91/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 92/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 93/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 94/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 95/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 96/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 97/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 98/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 99/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 100/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 101/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 102/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 103/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 104/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 105/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 106/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 107/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 108/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 109/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 110/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 111/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 112/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 113/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 114/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 115/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 116/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 117/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 118/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 119/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 120/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 121/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 122/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 123/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 124/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 125/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 126/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 127/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 128/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 129/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 130/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 131/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 132/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 133/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 134/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 135/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 136/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 137/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 138/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 139/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 140/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 141/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 142/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 143/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 144/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 145/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4995
# Epoch 146/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 147/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 148/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4995 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 149/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 150/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 151/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 152/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 153/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 154/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 155/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 156/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 157/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 158/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 159/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 160/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 161/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 162/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 163/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 164/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 165/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 166/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 167/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 168/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 169/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 170/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 171/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 172/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 173/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 174/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 175/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 176/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 177/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 178/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 179/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 180/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 181/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 182/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 183/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 184/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 185/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 186/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 187/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 188/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 189/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 190/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 191/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 192/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 193/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 194/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 195/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 196/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 197/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 198/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 199/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 200/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 201/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 202/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 203/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 204/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 205/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 206/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 207/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 208/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 209/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 210/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 211/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 212/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 213/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 214/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 215/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 216/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 217/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 218/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 219/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 220/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 221/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 222/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 223/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 224/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 225/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 226/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 227/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 228/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 229/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 230/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 231/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 232/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 233/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 234/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 235/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 236/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 237/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 238/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 239/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 240/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 241/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 242/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 243/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 244/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 245/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 246/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 247/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 248/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 249/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 250/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 251/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 252/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 253/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 254/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 255/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 256/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 257/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 258/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 259/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 260/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 261/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 262/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 263/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 264/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 265/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 266/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 267/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 268/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 269/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 270/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 271/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 272/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 273/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 274/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 275/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 276/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 277/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 278/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 279/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 280/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 281/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 282/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 283/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 284/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 285/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 286/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 287/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 288/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 289/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 290/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 291/300
# 495/495 [==============================] - 4s 8ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 292/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 293/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 294/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 295/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 296/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 297/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 298/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 299/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994
# Epoch 300/300
# 495/495 [==============================] - 4s 7ms/step - loss: 0.0206 - mean_iou: 0.4994 - val_loss: 0.0209 - val_mean_iou: 0.4994

# %%
# Save

t_model.save("weight/teacher_model3.h5")

# %%
# Get and resize test images

X_test = np.zeros(
    (n_test_images, im_height, im_width, im_chan), dtype=np.uint8)
sizes_test = []

sys.stdout.flush()
for n, id_ in tqdm_notebook(enumerate(range(n_test_images)), total=(n_test_images)):
    path = path_test
    img = load_img(path + "/" + str(id_) + ".png")
    x = img_to_array(img)[:, :, 1]
    sizes_test.append([x.shape[0], x.shape[1]])
    x = resize(x, (im_height, im_width, 1),
               mode="constant", preserve_range=True)
    X_test[n] = x
# Out:
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# Predict

t_model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_train = t_model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = t_model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = t_model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 495/495 [==============================] - 2s 4ms/step
# 495/495 [==============================] - 1s 2ms/step
# 55/55 [==============================] - 1s 11ms/step
# 30/30 [==============================] - 1s 22ms/step

# %%
# Create a list of upsampled test masks

preds_test_upsampled = []
for i in tnrange(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]),
                                       (sizes_test[i][0], sizes_test[i][1]),
                                       mode='constant', preserve_range=True))
# Out:
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# Show a result on a random sample

# Original image
print("Original Image")
ix = random.randint(0, len(preds_train_t))
plt.imshow(np.dstack((X_train[ix], X_train[ix], X_train[ix])))
plt.show()

# Mask image
print("Label")
tmp = np.squeeze(Y_train[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp, tmp, tmp)))
plt.show()

# Prediction image
print("Prediction")
tmp = np.squeeze(preds_train_t[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp, tmp, tmp)))
plt.show()
# Out:
# Original Image
# Label
# Prediction
